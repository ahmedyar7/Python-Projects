# %% [markdown]
# ## Importing the Class that contain the mathplotlib and the numpy

# %%
from trig_function_plot import TrignometricFunctionPlot

trig_function_plot = TrignometricFunctionPlot()

# %% [markdown]
# ### Sin Function

# %%
trig_function_plot.sin_function()

# %% [markdown]
# ### Cos Function

# %%
trig_function_plot.cos_funtion()

# %% [markdown]
# ### Tan Function

# %%
trig_function_plot.tan_funtion()

# %% [markdown]
# ### Cosh Function

# %%
trig_function_plot.cosh_funtion()
